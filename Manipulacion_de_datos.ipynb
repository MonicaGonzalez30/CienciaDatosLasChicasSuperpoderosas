# %%
def quick_sort_pirata(arreglo):
    izq = []
    der = []
    center = []
    
    if len(arreglo) == 0 or len(arreglo)==1:
        return arreglo
    
    else:
        
        piv = arreglo[0]
        
        for e in arreglo:
            if e<piv:
                izq.append(e)
            elif e==piv:
                center.append(e)
            elif e>piv:
                der.append(e)
        
        return quick_sort_pirata(izq)+center+quick_sort_pirata(der)
    

def merge_sort_pirata(arreglo):
    # Casos base
    if len(arreglo) == 0 or len(arreglo) == 1:
        return arreglo
    
    else:
        mitad = len(arreglo) // 2
        arr_izq = arreglo[:mitad]
        arr_der = arreglo[mitad:]
        
        arr_izq = merge_sort_pirata(arr_izq)
        arr_der = merge_sort_pirata(arr_der)
        
        a = 0
        b = 0
        c = 0
        
        while a < len(arr_izq) and b < len(arr_der):
            if arr_izq[a] < arr_der[b]:
                arreglo[c] = arr_izq[a]
                a += 1
            else:
                arreglo[c] = arr_der[b]
                b += 1
            c += 1
        
        while a < len(arr_izq):
            arreglo[c] = arr_izq[a]
            a += 1
            c += 1
        
        while b < len(arr_der):
            arreglo[c] = arr_der[b]
            b += 1
            c += 1
            
        return arreglo

# %%
import matplotlib.pyplot as plt
import pandas as pd

arch = pd.read_csv('Tiempos.csv')
arch
# Out:
#             Unnamed: 0 Tiempo promedio (s)   Unnamed: 2 Unnamed: 3
# 0  Tamaño del problema         MiMergeSort  MiQuickSort  NumpySort
# 1                   10                 NaN          NaN        NaN
# 2                  100                 NaN          NaN        NaN
# 3                 1000                 NaN          NaN        NaN
# 4                10000                 NaN          NaN        NaN
# 5               100000                 NaN          NaN        NaN
# 6              1000000                 NaN          NaN        NaN
# 7             10000000                 NaN          NaN        NaN
# 8            100000000                 NaN          NaN        NaN

# %%
#arch.at[1, 'Tiempo promedio (s)']= 'Hola XD'
#arch.iloc[0]
arch.drop(0, inplace=True)
arch
# Out:
#   Unnamed: 0 Tiempo promedio (s) Unnamed: 2 Unnamed: 3
# 1         10                 NaN        NaN        NaN
# 2        100                 NaN        NaN        NaN
# 3       1000                 NaN        NaN        NaN
# 4      10000                 NaN        NaN        NaN
# 5     100000                 NaN        NaN        NaN
# 6    1000000                 NaN        NaN        NaN
# 7   10000000                 NaN        NaN        NaN
# 8  100000000                 NaN        NaN        NaN

# %%
arch = arch.rename(columns={'Unnamed: 0': 'Tamaño del Problema'})
arch = arch.rename(columns={'Tiempo promedio (s)': 'Merge Sort'})
arch = arch.rename(columns={'Unnamed: 2': 'Quick Sort'})
arch = arch.rename(columns={'Unnamed: 3': 'Numpy Sort'})

arch
# Out:
#   Tamaño del Problema Merge Sort Quick Sort Numpy Sort
# 1                  10        NaN        NaN        NaN
# 2                 100        NaN        NaN        NaN
# 3                1000        NaN        NaN        NaN
# 4               10000        NaN        NaN        NaN
# 5              100000        NaN        NaN        NaN
# 6             1000000        NaN        NaN        NaN
# 7            10000000        NaN        NaN        NaN
# 8           100000000        NaN        NaN        NaN

# %%
import numpy as np

'''arreglo1 = np.random.random(10)
arreglo2 = np.random.random(100)
arreglo3 = np.random.random(1000)
arreglo4 = np.random.random(10000)
arreglo5 = np.random.random(100000)
arreglo6 = np.random.random(1000000)
arreglo7 = np.random.random(10000000)
arreglo8 = np.random.random(100000000)
tiempo_ejecucion1 = %timeit -o merge_sort_pirata(arreglo1)
tiempo_ejecucion2 = %timeit -o merge_sort_pirata(arreglo2)
tiempo_ejecucion3 = %timeit -o merge_sort_pirata(arreglo3)
tiempo_ejecucion4 = %timeit -o merge_sort_pirata(arreglo4)
tiempo_ejecucion5 = %timeit -o merge_sort_pirata(arreglo5)
tiempo_ejecucion6 = %timeit -o merge_sort_pirata(arreglo6)
tiempo_ejecucion7 = %timeit -o merge_sort_pirata(arreglo7)
tiempo_ejecucion8 = %timeit -o merge_sort_pirata(arreglo8)
arch.loc[1, 'Merge Sort'] = tiempo_ejecucion1.best
arch.loc[2, 'Merge Sort'] = tiempo_ejecucion2.best
arch.loc[3, 'Merge Sort'] = tiempo_ejecucion3.best
arch.loc[4, 'Merge Sort'] = tiempo_ejecucion4.best
arch.loc[5, 'Merge Sort'] = tiempo_ejecucion5.best
arch.loc[6, 'Merge Sort'] = tiempo_ejecucion6.best
arch.loc[7, 'Merge Sort'] = tiempo_ejecucion7.best
arch.loc[8, 'Merge Sort'] = tiempo_ejecucion8.best'''


'''
timepo1 = 2.5096795000001748e-05
tiempo2 =  0.00040968890199999917
tiempo3 = 0.0053817663600000286
tiempo4 =  0.06938844230000143
tiempo5 = 0.8578789370000095
tiempo6 =  11.665475320999803
timepo7 =

'''
# Out:
# '\ntimepo1 = 2.5096795000001748e-05\ntiempo2 =  0.00040968890199999917\ntiempo3 = 0.0053817663600000286\ntiempo4 =  0.06938844230000143\ntiempo5 = 0.8578789370000095\ntiempo6 =  11.665475320999803\ntimepo7 =\n\n'

# %%
arch.loc[1:6, 'Merge Sort'] = [2.5096795000001748e-05, 0.00040968890199999917
                               ,0.0053817663600000286, 0.06938844230000143,
                               0.8578789370000095, 11.665475320999803 ]

# %%
arch
# Out:
#   Tamaño del Problema Merge Sort Quick Sort Numpy Sort
# 1                  10   0.000025        NaN        NaN
# 2                 100    0.00041        NaN        NaN
# 3                1000   0.005382        NaN        NaN
# 4               10000   0.069388        NaN        NaN
# 5              100000   0.857879        NaN        NaN
# 6             1000000  11.665475        NaN        NaN
# 7            10000000        NaN        NaN        NaN
# 8           100000000        NaN        NaN        NaN

# %%
arch.loc[7, 'Merge Sort']=137.02669420699976

# %%
arch
# Out:
#   Tamaño del Problema  Merge Sort Quick Sort Numpy Sort
# 1                  10    0.000025        NaN        NaN
# 2                 100     0.00041        NaN        NaN
# 3                1000    0.005382        NaN        NaN
# 4               10000    0.069388        NaN        NaN
# 5              100000    0.857879        NaN        NaN
# 6             1000000   11.665475        NaN        NaN
# 7            10000000  137.026694        NaN        NaN
# 8           100000000         NaN        NaN        NaN

# %%
import matplotlib.pyplot as plt

x = arch['Merge Sort'] # Tiempos de ejecución del algoritmo Merge Sort
y = arch['Tamaño del Problema'] # Tamaños del problema

plt.plot(y, x) # Graficar los tiempos en función del tamaño del problema
plt.title("Tiempo del Merge Sort") # Establecer el título del gráfico
plt.xlabel("Tamaño del Problema") # Etiqueta del eje x
plt.ylabel("Tiempo (segundos)") # Etiqueta del eje y
plt.show() # Mostrar el gráfico

# %%
arreglo1 = np.random.random(10)
arreglo2 = np.random.random(100)
arreglo3 = np.random.random(1000)
arreglo4 = np.random.random(10000)
arreglo5 = np.random.random(100000)
arreglo6 = np.random.random(1000000)

tiempo_ejecucion1 = %timeit -o quick_sort_pirata(arreglo1)
tiempo_ejecucion2 = %timeit -o quick_sort_pirata(arreglo2)
tiempo_ejecucion3 = %timeit -o quick_sort_pirata(arreglo3)
tiempo_ejecucion4 = %timeit -o quick_sort_pirata(arreglo4)
tiempo_ejecucion5 = %timeit -o quick_sort_pirata(arreglo5)
tiempo_ejecucion6 = %timeit -o quick_sort_pirata(arreglo6)

arch.loc[1, 'Quick Sort'] = tiempo_ejecucion1.best
arch.loc[2, 'Quick Sort'] = tiempo_ejecucion2.best
arch.loc[3, 'Quick Sort'] = tiempo_ejecucion3.best
arch.loc[4, 'Quick Sort'] = tiempo_ejecucion4.best
arch.loc[5, 'Quick Sort'] = tiempo_ejecucion5.best
arch.loc[6, 'Quick Sort'] = tiempo_ejecucion6.best
# Out:
# 8.24 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 85.7 µs ± 961 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 1.33 ms ± 30.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 18.8 ms ± 124 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 256 ms ± 6.73 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 4.23 s ± 317 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
arreglo7 = np.random.random(10000000)
tiempo_ejecucion7 = %timeit -o quick_sort_pirata(arreglo7)
arch.loc[7, 'Quick Sort'] = tiempo_ejecucion7.best
# Out:
# 1min 1s ± 4.56 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
arch
# Out:
#   Tamaño del Problema  Merge Sort Quick Sort Numpy Sort
# 1                  10    0.000025   0.000006        NaN
# 2                 100     0.00041   0.000084        NaN
# 3                1000    0.005382   0.001303        NaN
# 4               10000    0.069388    0.01863        NaN
# 5              100000    0.857879   0.245118        NaN
# 6             1000000   11.665475   4.033845        NaN
# 7            10000000  137.026694   54.86684        NaN
# 8           100000000         NaN        NaN        NaN

# %%
x = arch['Quick Sort'] # Tiempos de ejecución del algoritmo Quick Sort
y = arch['Tamaño del Problema'] # Tamaños del problema

plt.plot(y, x) # Graficar los tiempos en función del tamaño del problema
plt.title("Tiempo del Quick Sort") # Establecer el título del gráfico
plt.xlabel("Tamaño del Problema") # Etiqueta del eje x
plt.ylabel("Tiempo (segundos)") # Etiqueta del eje y
plt.show() # Mostrar el gráfico

# %%
arreglo1 = np.random.random(10)
arreglo2 = np.random.random(100)
arreglo3 = np.random.random(1000)
arreglo4 = np.random.random(10000)
arreglo5 = np.random.random(100000)
arreglo6 = np.random.random(1000000)

tiempo_ejecucion1 = %timeit -o np.sort(arreglo1)
tiempo_ejecucion2 = %timeit -o np.sort(arreglo2)
tiempo_ejecucion3 = %timeit -o np.sort(arreglo3)
tiempo_ejecucion4 = %timeit -o np.sort(arreglo4)
tiempo_ejecucion5 = %timeit -o np.sort(arreglo5)
tiempo_ejecucion6 = %timeit -o np.sort(arreglo6)

arch.loc[1, 'Numpy Sort'] = tiempo_ejecucion1.best
arch.loc[2, 'Numpy Sort'] = tiempo_ejecucion2.best
arch.loc[3, 'Numpy Sort'] = tiempo_ejecucion3.best
arch.loc[4, 'Numpy Sort'] = tiempo_ejecucion4.best
arch.loc[5, 'Numpy Sort'] = tiempo_ejecucion5.best
arch.loc[6, 'Numpy Sort'] = tiempo_ejecucion6.best
# Out:
# 1.4 µs ± 16.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 2.03 µs ± 81.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 12.9 µs ± 308 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 483 µs ± 25.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 6.39 ms ± 136 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 76.4 ms ± 3.36 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
arch
# Out:
#   Tamaño del Problema  Merge Sort Quick Sort Numpy Sort
# 1                  10    0.000025   0.000006   0.000001
# 2                 100     0.00041   0.000084   0.000002
# 3                1000    0.005382   0.001303   0.000013
# 4               10000    0.069388    0.01863   0.000463
# 5              100000    0.857879   0.245118   0.006239
# 6             1000000   11.665475   4.033845   0.073725
# 7            10000000  137.026694   54.86684        NaN
# 8           100000000         NaN        NaN        NaN

# %%
x = arch['Numpy Sort'] # Tiempos de ejecución del algoritmo Numpy sort
y = arch['Tamaño del Problema'] # Tamaños del problema

plt.plot(y, x) # Graficar los tiempos en función del tamaño del problema
plt.title("Tiempo del Numpy Sort") # Establecer el título del gráfico
plt.xlabel("Tamaño del Problema") # Etiqueta del eje x
plt.ylabel("Tiempo (segundos)") # Etiqueta del eje y
plt.show() # Mostrar el gráfico

# %%
arreglo7 = np.random.random(10000000)
tiempo_ejecucion7 = %timeit -o np.sort(arreglo7)
arch.loc[7, 'Numpy Sort'] = tiempo_ejecucion7.best
# Out:
# 913 ms ± 33.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
arch
# Out:
#   Tamaño del Problema  Merge Sort Quick Sort Numpy Sort
# 1                  10    0.000025   0.000006   0.000001
# 2                 100     0.00041   0.000084   0.000002
# 3                1000    0.005382   0.001303   0.000013
# 4               10000    0.069388    0.01863   0.000463
# 5              100000    0.857879   0.245118   0.006239
# 6             1000000   11.665475   4.033845   0.073725
# 7            10000000  137.026694   54.86684    0.86838
# 8           100000000         NaN        NaN        NaN

# %%
arreglo8 = np.random.random(100000000)
tiempo_ejecucion8 = %timeit -o np.sort(arreglo8)
arch.loc[8, 'Numpy Sort'] = tiempo_ejecucion8.best
# Out:
# 10.4 s ± 286 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
arch
# Out:
#   Tamaño del Problema  Merge Sort Quick Sort Numpy Sort
# 1                  10    0.000025   0.000006   0.000001
# 2                 100     0.00041   0.000084   0.000002
# 3                1000    0.005382   0.001303   0.000013
# 4               10000    0.069388    0.01863   0.000463
# 5              100000    0.857879   0.245118   0.006239
# 6             1000000   11.665475   4.033845   0.073725
# 7            10000000  137.026694   54.86684    0.86838
# 8           100000000         NaN        NaN  10.059855

# %%
x = arch['Numpy Sort'] # Tiempos de ejecución del algoritmo Numpy sort
y = arch['Tamaño del Problema'] # Tamaños del problema

plt.plot(y, x) # Graficar los tiempos en función del tamaño del problema
plt.title("Tiempo del Numpy Sort") # Establecer el título del gráfico
plt.xlabel("Tamaño del Problema") # Etiqueta del eje x
plt.ylabel("Tiempo (segundos)") # Etiqueta del eje y
plt.show() # Mostrar el gráfico
